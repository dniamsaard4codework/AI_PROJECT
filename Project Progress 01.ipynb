# %%
# !pip install mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.9b7-py3-none-any.whl (73 kB)
#      -------------------------------------- 73.1/73.1 kB 998.4 kB/s eta 0:00:00
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (from mplfinance) (1.4.4)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from mplfinance) (3.5.2)
# Requirement already satisfied: numpy>=1.17 in d:\anaconda\lib\site-packages (from matplotlib->mplfinance) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib->mplfinance) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->mplfinance) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib->mplfinance) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib->mplfinance) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas->mplfinance) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.9b7

# %%
import pandas as pd
import mplfinance as mpf
import yfinance as yf
import matplotlib.pyplot as plt

# %%
data = yf.download('AAPL', start='2018-01-01', end='2022-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = data.copy()

# %%
df['sma_short'] = df.Close.rolling(24).mean()
df['sma_long'] = df.Close.rolling(52).mean()

# %%
sma_short = mpf.make_addplot(df['sma_short'], color='orange')
sma_long = mpf.make_addplot(df['sma_long'], color='y')

# %%
sma_list = [sma_short, sma_long]

# %%
mpf.plot(df,style='yahoo', type='candle', addplot = sma_list, figsize=(14,6))
# Out:
# D:\Anaconda\lib\site-packages\mplfinance\_arg_validators.py:83: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   42.540001   43.075001   42.314999   43.064999   40.888073
# 2018-01-03   43.132500   43.637501   42.990002   43.057499   40.880951
# 2018-01-04   43.134998   43.367500   43.020000   43.257500   41.070835
# 2018-01-05   43.360001   43.842499   43.262501   43.750000   41.538441
# 2018-01-08   43.587502   43.902500   43.482498   43.587502   41.384159
# ...                ...         ...         ...         ...         ...
# 2021-12-27  177.089996  180.419998  177.070007  180.330002  179.016129
# 2021-12-28  180.160004  181.330002  178.529999  179.289993  177.983688
# 2021-12-29  179.330002  180.630005  178.139999  179.380005  178.073029
# 2021-12-30  179.470001  180.570007  178.089996  178.199997  176.901627
# 2021-12-31  178.089996  179.229996  177.259995  177.570007  176.276230
#
#                Volume   sma_short    sma_long
# Date
# 2018-01-02  102223600         NaN         NaN
# 2018-01-03  118071600         NaN         NaN
# 2018-01-04   89738400         NaN         NaN
# 2018-01-05   94640000         NaN         NaN
# 2018-01-08   82271200         NaN         NaN
# ...               ...         ...         ...
# 2021-12-27   74919600  169.601667  158.933078
# 2021-12-28   79144300  170.362917  159.671155
# 2021-12-29   62348900  171.111667  160.356155
# 2021-12-30   59773000  171.789167  160.997693
# 2021-12-31   64062300  172.654167  161.594232
#
# [1008 rows x 8 columns]

# %%
df['trend'] = df['sma_short'] > df['sma_long']

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   42.540001   43.075001   42.314999   43.064999   40.888073
# 2018-01-03   43.132500   43.637501   42.990002   43.057499   40.880951
# 2018-01-04   43.134998   43.367500   43.020000   43.257500   41.070835
# 2018-01-05   43.360001   43.842499   43.262501   43.750000   41.538441
# 2018-01-08   43.587502   43.902500   43.482498   43.587502   41.384159
# ...                ...         ...         ...         ...         ...
# 2021-12-27  177.089996  180.419998  177.070007  180.330002  179.016129
# 2021-12-28  180.160004  181.330002  178.529999  179.289993  177.983688
# 2021-12-29  179.330002  180.630005  178.139999  179.380005  178.073029
# 2021-12-30  179.470001  180.570007  178.089996  178.199997  176.901627
# 2021-12-31  178.089996  179.229996  177.259995  177.570007  176.276230
#
#                Volume   sma_short    sma_long  trend
# Date
# 2018-01-02  102223600         NaN         NaN  False
# 2018-01-03  118071600         NaN         NaN  False
# 2018-01-04   89738400         NaN         NaN  False
# 2018-01-05   94640000         NaN         NaN  False
# 2018-01-08   82271200         NaN         NaN  False
# ...               ...         ...         ...    ...
# 2021-12-27   74919600  169.601667  158.933078   True
# 2021-12-28   79144300  170.362917  159.671155   True
# 2021-12-29   62348900  171.111667  160.356155   True
# 2021-12-30   59773000  171.789167  160.997693   True
# 2021-12-31   64062300  172.654167  161.594232   True
#
# [1008 rows x 9 columns]

# %%
df['trend_shift'] = df.trend.shift(1)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   42.540001   43.075001   42.314999   43.064999   40.888073
# 2018-01-03   43.132500   43.637501   42.990002   43.057499   40.880951
# 2018-01-04   43.134998   43.367500   43.020000   43.257500   41.070835
# 2018-01-05   43.360001   43.842499   43.262501   43.750000   41.538441
# 2018-01-08   43.587502   43.902500   43.482498   43.587502   41.384159
# ...                ...         ...         ...         ...         ...
# 2021-12-27  177.089996  180.419998  177.070007  180.330002  179.016129
# 2021-12-28  180.160004  181.330002  178.529999  179.289993  177.983688
# 2021-12-29  179.330002  180.630005  178.139999  179.380005  178.073029
# 2021-12-30  179.470001  180.570007  178.089996  178.199997  176.901627
# 2021-12-31  178.089996  179.229996  177.259995  177.570007  176.276230
#
#                Volume   sma_short    sma_long  trend trend_shift
# Date
# 2018-01-02  102223600         NaN         NaN  False         NaN
# 2018-01-03  118071600         NaN         NaN  False       False
# 2018-01-04   89738400         NaN         NaN  False       False
# 2018-01-05   94640000         NaN         NaN  False       False
# 2018-01-08   82271200         NaN         NaN  False       False
# ...               ...         ...         ...    ...         ...
# 2021-12-27   74919600  169.601667  158.933078   True        True
# 2021-12-28   79144300  170.362917  159.671155   True        True
# 2021-12-29   62348900  171.111667  160.356155   True        True
# 2021-12-30   59773000  171.789167  160.997693   True        True
# 2021-12-31   64062300  172.654167  161.594232   True        True
#
# [1008 rows x 10 columns]

# %%
df.loc[(df.trend == True) & (df.trend_shift == False),'action'] = 'buy'
df.loc[(df.trend == False) & (df.trend_shift == True),'action'] = 'sell'

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   42.540001   43.075001   42.314999   43.064999   40.888073
# 2018-01-03   43.132500   43.637501   42.990002   43.057499   40.880951
# 2018-01-04   43.134998   43.367500   43.020000   43.257500   41.070835
# 2018-01-05   43.360001   43.842499   43.262501   43.750000   41.538441
# 2018-01-08   43.587502   43.902500   43.482498   43.587502   41.384159
# ...                ...         ...         ...         ...         ...
# 2021-12-27  177.089996  180.419998  177.070007  180.330002  179.016129
# 2021-12-28  180.160004  181.330002  178.529999  179.289993  177.983688
# 2021-12-29  179.330002  180.630005  178.139999  179.380005  178.073029
# 2021-12-30  179.470001  180.570007  178.089996  178.199997  176.901627
# 2021-12-31  178.089996  179.229996  177.259995  177.570007  176.276230
#
#                Volume   sma_short    sma_long  trend trend_shift action
# Date
# 2018-01-02  102223600         NaN         NaN  False         NaN    NaN
# 2018-01-03  118071600         NaN         NaN  False       False    NaN
# 2018-01-04   89738400         NaN         NaN  False       False    NaN
# 2018-01-05   94640000         NaN         NaN  False       False    NaN
# 2018-01-08   82271200         NaN         NaN  False       False    NaN
# ...               ...         ...         ...    ...         ...    ...
# 2021-12-27   74919600  169.601667  158.933078   True        True    NaN
# 2021-12-28   79144300  170.362917  159.671155   True        True    NaN
# 2021-12-29   62348900  171.111667  160.356155   True        True    NaN
# 2021-12-30   59773000  171.789167  160.997693   True        True    NaN
# 2021-12-31   64062300  172.654167  161.594232   True        True    NaN
#
# [1008 rows x 11 columns]

# %%
df[df.action == 'buy']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-16   44.662498   44.779999   44.404999   44.505001   42.427547
# 2018-05-10   46.935001   47.592499   46.912498   47.509998   45.292290
# 2018-07-27   48.747501   48.797501   47.525002   47.744999   45.691822
# 2019-02-14   42.427502   42.814999   42.345001   42.700001   41.326664
# 2019-07-05   50.837502   51.270000   50.724998   51.057499   49.605663
# 2020-05-04   72.292503   73.422501   71.580002   73.290001   71.861252
# 2020-11-10  115.550003  117.589996  114.129997  115.970001  114.419670
# 2021-04-21  132.360001  133.750000  131.300003  133.500000  131.912155
# 2021-06-30  136.169998  137.410004  135.869995  136.960007  135.560867
# 2021-11-09  150.199997  151.429993  150.059998  150.809998  149.711182
#
#                Volume   sma_short    sma_long  trend trend_shift action
# Date
# 2018-03-16  157618800   43.746771   43.137981   True       False    buy
# 2018-05-10  111957200   43.475625   43.473318   True       False    buy
# 2018-07-27   96096000   47.267813   47.247404   True       False    buy
# 2019-02-14   87342800   40.543437   40.507308   True       False    buy
# 2019-07-05   69062000   48.669792   48.604904   True       False    buy
# 2020-05-04  133568000   68.298229   67.957932   True       False    buy
# 2020-11-10  138023400  116.279584  116.091105   True       False    buy
# 2021-04-21   68847100  126.915000  126.843461   True       False    buy
# 2021-06-30   63261400  129.540833  129.425192   True       False    buy
# 2021-11-09   56787900  147.745834  147.668846   True       False    buy

# %%
df.loc[df['action'] == 'buy', 'marker_position'] = df['Low'] *0.95
df.loc[df['action'] == 'sell', 'marker_position'] = df['High'] *1.05

# %%
df[df.marker_position.notnull()]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-16   44.662498   44.779999   44.404999   44.505001   42.427547
# 2018-04-20   42.650002   42.805000   41.357498   41.430000   39.496098
# 2018-05-10   46.935001   47.592499   46.912498   47.509998   45.292290
# 2018-07-16   47.880001   48.162498   47.605000   47.727501   45.675083
# 2018-07-27   48.747501   48.797501   47.525002   47.744999   45.691822
# 2018-11-01   54.762501   55.590000   54.202499   55.555000   53.352436
# 2019-02-14   42.427502   42.814999   42.345001   42.700001   41.326664
# 2019-05-29   44.105000   44.837502   44.000000   44.345001   43.084034
# 2019-07-05   50.837502   51.270000   50.724998   51.057499   49.605663
# 2020-03-09   65.937500   69.522499   65.750000   66.542503   65.245293
# 2020-05-04   72.292503   73.422501   71.580002   73.290001   71.861252
# 2020-10-07  114.620003  115.550003  114.129997  115.080002  113.346016
# 2020-11-10  115.550003  117.589996  114.129997  115.970001  114.419670
# 2021-03-03  124.809998  125.709999  121.839996  122.059998  120.608215
# 2021-04-21  132.360001  133.750000  131.300003  133.500000  131.912155
# 2021-06-01  125.080002  125.349998  123.940002  124.279999  123.010399
# 2021-06-30  136.169998  137.410004  135.869995  136.960007  135.560867
# 2021-10-05  139.490005  142.240005  139.360001  141.110001  139.877731
# 2021-11-09  150.199997  151.429993  150.059998  150.809998  149.711182
#
#                Volume   sma_short    sma_long  trend trend_shift action  \
# Date
# 2018-03-16  157618800   43.746771   43.137981   True       False    buy
# 2018-04-20  261964400   42.852709   43.017692  False        True   sell
# 2018-05-10  111957200   43.475625   43.473318   True       False    buy
# 2018-07-16   60172400   46.894271   46.924567  False        True   sell
# 2018-07-27   96096000   47.267813   47.247404   True       False    buy
# 2018-11-01  233292800   55.225729   55.269664  False        True   sell
# 2019-02-14   87342800   40.543437   40.507308   True       False    buy
# 2019-05-29  113924800   48.640729   48.765048  False        True   sell
# 2019-07-05   69062000   48.669792   48.604904   True       False    buy
# 2020-03-09  286744800   76.504895   76.617884  False        True   sell
# 2020-05-04  133568000   68.298229   67.957932   True       False    buy
# 2020-10-07   96849000  113.608333  114.250528  False        True   sell
# 2020-11-10  138023400  116.279584  116.091105   True       False    buy
# 2021-03-03  112966300  130.963333  131.652885  False        True   sell
# 2021-04-21   68847100  126.915000  126.843461   True       False    buy
# 2021-06-01   67637100  127.436667  127.688654  False        True   sell
# 2021-06-30   63261400  129.540833  129.425192   True       False    buy
# 2021-10-05   80861100  147.388749  147.654615  False        True   sell
# 2021-11-09   56787900  147.745834  147.668846   True       False    buy
#
#             marker_position
# Date
# 2018-03-16        42.184749
# 2018-04-20        44.945250
# 2018-05-10        44.566874
# 2018-07-16        50.570623
# 2018-07-27        45.148751
# 2018-11-01        58.369500
# 2019-02-14        40.227751
# 2019-05-29        47.079377
# 2019-07-05        48.188749
# 2020-03-09        72.998624
# 2020-05-04        68.001002
# 2020-10-07       121.327503
# 2020-11-10       108.423497
# 2021-03-03       131.995499
# 2021-04-21       124.735003
# 2021-06-01       131.617498
# 2021-06-30       129.076495
# 2021-10-05       149.352006
# 2021-11-09       142.556998

# %%
b = df.loc[df.action == 'buy']

s = df.loc[df.action == 'sell']

# %%
b
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-16   44.662498   44.779999   44.404999   44.505001   42.427547
# 2018-05-10   46.935001   47.592499   46.912498   47.509998   45.292290
# 2018-07-27   48.747501   48.797501   47.525002   47.744999   45.691822
# 2019-02-14   42.427502   42.814999   42.345001   42.700001   41.326664
# 2019-07-05   50.837502   51.270000   50.724998   51.057499   49.605663
# 2020-05-04   72.292503   73.422501   71.580002   73.290001   71.861252
# 2020-11-10  115.550003  117.589996  114.129997  115.970001  114.419670
# 2021-04-21  132.360001  133.750000  131.300003  133.500000  131.912155
# 2021-06-30  136.169998  137.410004  135.869995  136.960007  135.560867
# 2021-11-09  150.199997  151.429993  150.059998  150.809998  149.711182
#
#                Volume   sma_short    sma_long  trend trend_shift action  \
# Date
# 2018-03-16  157618800   43.746771   43.137981   True       False    buy
# 2018-05-10  111957200   43.475625   43.473318   True       False    buy
# 2018-07-27   96096000   47.267813   47.247404   True       False    buy
# 2019-02-14   87342800   40.543437   40.507308   True       False    buy
# 2019-07-05   69062000   48.669792   48.604904   True       False    buy
# 2020-05-04  133568000   68.298229   67.957932   True       False    buy
# 2020-11-10  138023400  116.279584  116.091105   True       False    buy
# 2021-04-21   68847100  126.915000  126.843461   True       False    buy
# 2021-06-30   63261400  129.540833  129.425192   True       False    buy
# 2021-11-09   56787900  147.745834  147.668846   True       False    buy
#
#             marker_position
# Date
# 2018-03-16        42.184749
# 2018-05-10        44.566874
# 2018-07-27        45.148751
# 2019-02-14        40.227751
# 2019-07-05        48.188749
# 2020-05-04        68.001002
# 2020-11-10       108.423497
# 2021-04-21       124.735003
# 2021-06-30       129.076495
# 2021-11-09       142.556998

# %%
s
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-04-20   42.650002   42.805000   41.357498   41.430000   39.496098
# 2018-07-16   47.880001   48.162498   47.605000   47.727501   45.675083
# 2018-11-01   54.762501   55.590000   54.202499   55.555000   53.352436
# 2019-05-29   44.105000   44.837502   44.000000   44.345001   43.084034
# 2020-03-09   65.937500   69.522499   65.750000   66.542503   65.245293
# 2020-10-07  114.620003  115.550003  114.129997  115.080002  113.346016
# 2021-03-03  124.809998  125.709999  121.839996  122.059998  120.608215
# 2021-06-01  125.080002  125.349998  123.940002  124.279999  123.010399
# 2021-10-05  139.490005  142.240005  139.360001  141.110001  139.877731
#
#                Volume   sma_short    sma_long  trend trend_shift action  \
# Date
# 2018-04-20  261964400   42.852709   43.017692  False        True   sell
# 2018-07-16   60172400   46.894271   46.924567  False        True   sell
# 2018-11-01  233292800   55.225729   55.269664  False        True   sell
# 2019-05-29  113924800   48.640729   48.765048  False        True   sell
# 2020-03-09  286744800   76.504895   76.617884  False        True   sell
# 2020-10-07   96849000  113.608333  114.250528  False        True   sell
# 2021-03-03  112966300  130.963333  131.652885  False        True   sell
# 2021-06-01   67637100  127.436667  127.688654  False        True   sell
# 2021-10-05   80861100  147.388749  147.654615  False        True   sell
#
#             marker_position
# Date
# 2018-04-20        44.945250
# 2018-07-16        50.570623
# 2018-11-01        58.369500
# 2019-05-29        47.079377
# 2020-03-09        72.998624
# 2020-10-07       121.327503
# 2021-03-03       131.995499
# 2021-06-01       131.617498
# 2021-10-05       149.352006

# %%
plt.figure(figsize=(16,9))
plt.plot(df.Close, label='Close Price')
plt.plot(df.sma_short, label='SMA 12')
plt.plot(df.sma_long, label='SMA 26')
plt.plot(b.marker_position, 'g^', markersize=10)
plt.plot(s.marker_position, 'rv', markersize=10)
plt.legend()

# %% [markdown]
# ## Make the prediction here

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df.dropna(subset=["sma_short","sma_long"],inplace=True)
df.isnull().sum()
# Out:
# Open                 0
# High                 0
# Low                  0
# Close                0
# Adj Close            0
# Volume               0
# sma_short            0
# sma_long             0
# trend                0
# trend_shift          0
# action             938
# marker_position    938
# dtype: int64

# %%
X = df[["Open","High","Low","Volume","sma_short","sma_long"]]
y = df["Close"]
df.isnull().sum()
# Out:
# Open                 0
# High                 0
# Low                  0
# Close                0
# Adj Close            0
# Volume               0
# sma_short            0
# sma_long             0
# trend                0
# trend_shift          0
# action             938
# marker_position    938
# dtype: int64

# %%
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.2 , shuffle=False,random_state = 42)

# %%
model = RandomForestRegressor(n_estimators=100,random_state=0)
model.fit(train_x,train_y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
pred_y = model.predict(test_x)

# %%
# Plot the predicted vs. actual stock prices
plt.plot(test_y.index, test_y.values, label='Actual')
plt.plot(test_y.index, pred_y, label='Predicted')
plt.legend()
plt.show()

# %%
# Calculate the Mean Squared Error (MSE) and R-squared
mse = metrics.mean_squared_error(test_y, pred_y)
r2 = metrics.r2_score(test_y, pred_y)

print(mse)
print(r2)
# Out:
# 151.00301105136987
# 0.2542868289469673
